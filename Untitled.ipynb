# %%
import pandas as pd

# %%
file = pd.read_csv("city_county.csv")
file.dropna()
file.head()
# Out:
#    ZIP          X          Y ZIP_CLASS        CITY  STATE STATECODE  \
# 0  501 -73.046388  40.813078         U  HOLTSVILLE     36        NY
# 1  544 -73.049288  40.813223         U  HOLTSVILLE     36        NY
# 2  601 -66.723627  18.165950       NaN    ADJUNTAS     72        PR
# 3  602 -67.186553  18.383005       NaN      AGUADA     72        PR
# 4  603 -67.151954  18.433236       NaN   AGUADILLA     72        PR
#
#      STATENAME  COUNTY   COUNTYNM  ...  AREACODE  AREACODES  TIMEZONE  \
# 0     NEW YORK     103    SUFFOLK  ...       631        631   EASTERN
# 1     NEW YORK     103    SUFFOLK  ...       631        631   EASTERN
# 2  PUERTO RICO       1   ADJUNTAS  ...       787    787/939  ATLANTIC
# 3  PUERTO RICO       3     AGUADA  ...       787    787/939  ATLANTIC
# 4  PUERTO RICO       5  AGUADILLA  ...       787    787/939  ATLANTIC
#
#   GMTOFFSET  DST      PONAME ALIAS_CITY  \
# 0        -5    Y  HOLTSVILLE        NaN
# 1        -5    Y  HOLTSVILLE        NaN
# ...

# %%
file = pd.read_csv("county_income.csv")
file.dropna()
file.head()
# Out:
#    Year  State  County ID State / County Name All Ages SAIPE Poverty Universe  \
# 0  2017      0          0       United States                     317,741,588
# 1  2016      0          0       United States                     315,165,470
# 2  2015      0          0       United States                     313,476,400
# 3  2014      0          0       United States                     310,899,910
# 4  2013      0          0       United States                     308,196,783
#
#   All Ages in Poverty Count All Ages in Poverty Count LB 90%  \
# 0                42,583,651                       42,342,619
# 1                44,268,996                       44,022,086
# 2                46,153,077                       45,878,016
# 3                48,208,387                       47,966,830
# 4                48,810,868                       48,554,692
#
#   All Ages in Poverty Count UB 90%  \
# 0                       42,824,683
# 1                       44,515,906
# ...
