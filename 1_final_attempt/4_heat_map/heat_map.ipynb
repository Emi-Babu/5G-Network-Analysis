# %% [markdown]
# # Heat Map Creation with Weight in Population by County Using gmaps
# # Markers for the Top 10 Most Populated Counties

# %% [markdown]
# ### Import necessary dependencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from config import gkey

# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %% [markdown]
# ## Import Dataframe with coordinates to plot the Heat Map

# %%
heat_map_df = pd.read_csv('../3_coordinates/output/coordinates_pd.csv')
heat_map_df.head()
# Out:
#    State                                  Name  Population  Median Age  \
# 0     72        Corozal Municipio, Puerto Rico     34933.0        38.1
# 1     72        Maunabo Municipio, Puerto Rico     11297.0        43.5
# 2     72       Peñuelas Municipio, Puerto Rico     21661.0        36.4
# 3     72          Ponce Municipio, Puerto Rico    148863.0        39.5
# 4     72  San Sebastián Municipio, Puerto Rico     38970.0        42.0
#
#    Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0           14752.0             7887.0        19146.0     54.807775
# 1           17636.0             8830.0         5945.0     52.624591
# 2           16868.0             7983.0        12379.0     57.148793
# 3           16561.0            10775.0        75187.0     50.507514
# 4           14275.0             8072.0        21472.0     55.098794
#
#    Unemployment Rate  Households with Internet  \
# 0           9.435205                   11026.0
# 1           6.506152                    3976.0
# 2           7.391164                    7132.0
# 3           4.711043                   53341.0
# 4           8.486015                   14278.0
#
#    Households with Just Cell Data Plan  Households with DSL or Fiber Optic  \
# 0                               2381.0                              2268.0
# 1                                434.0                              1078.0
# 2                               1361.0                              2329.0
# 3                               5613.0                             18366.0
# 4                               1525.0                              2446.0
#
#    Households with Broadband Any Type  Households with Celular Data Plan  \
# 0                              5021.0                             4088.0
# 1                              1577.0                              987.0
# 2                              3877.0                             3090.0
# 3                             25211.0                            17691.0
# 4                              4743.0                             2737.0
#
#    Households with Just DSL or Fiber Optic  \
# 0                                    706.0
# 1                                    512.0
# 2                                    736.0
# 3                                   6802.0
# 4                                   1335.0
#
#    Households with Satellite Internet  \
# 0                               361.0
# 1                                77.0
# 2                               181.0
# 3                              1210.0
# 4                               829.0
#
#    Households with Just Satellite Internet  Households with No Internet  \
# 0                                    161.0                       5686.0
# 1                                     37.0                       2157.0
# 2                                     27.0                       2972.0
# 3                                    510.0                      25042.0
# 4                                    456.0                       8622.0
#
#          Lat        Lng
# 0  18.341062 -66.316836
# 1  18.007189 -65.899329
# 2  18.063358 -66.727390
# 3  18.011077 -66.614062
# 4  18.335476 -66.994679

# %% [markdown]
# ## Heat Map Weighted in Population with Markers for the Ten Most Populated Cities

# %% [markdown]
# ### Heat Map Weighted in Population

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = heat_map_df[["Lat", "Lng"]].astype(float)
# Define the center of the map as the middle of all latitudes and longitudes
center_lat = (heat_map_df["Lat"].max() + heat_map_df["Lat"].min()) /2
center_lng = (heat_map_df["Lng"].max() + heat_map_df["Lng"].min()) /2
# Store the population from the dataframe into a variable
population = heat_map_df["Population"].astype(float)
# Define the max intensity of the heatmap as 2.5 times the max population
max_intensity = population.max()*2.5
# Create a population Heatmap layer
fig = gmaps.figure(center = [center_lat,center_lng], zoom_level=4)
# Create the heat layer weighted in population
heat_layer = gmaps.heatmap_layer(locations, weights=population, 
                                 dissipating=False, max_intensity = max_intensity,
                                 point_radius = 5)
# Add the heat layer to the map
fig.add_layer(heat_layer)
# Show the map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Selection of the Top Ten Most Populated Counties

# %%
# Sort Counties by population in descending order
top_ten = heat_map_df.sort_values(by=['Population'], ascending=False)
# Reset index and delete the previous one
top_ten = top_ten.reset_index(drop=True)
# Store the top 10 in the dataframe
top_ten = top_ten.head(10)
# Print the dataframe
top_ten
# Out:
#    State                            Name  Population  Median Age  \
# 0      6  Los Angeles County, California  10105722.0        36.0
# 1     17           Cook County, Illinois   5238541.0        36.4
# 2     48            Harris County, Texas   4525519.0        33.1
# 3      4        Maricopa County, Arizona   4155501.0        36.0
# 4      6    San Diego County, California   3283665.0        35.4
# 5      6       Orange County, California   3155816.0        37.5
# 6     12      Miami-Dade County, Florida   2702602.0        39.5
# 7     36          Kings County, New York   2635121.0        34.8
# 8     48            Dallas County, Texas   2552213.0        33.3
# 9      6    Riverside County, California   2355002.0        35.0
#
#    Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0           61015.0            30798.0      1688505.0     16.708405
# 1           59426.0            33722.0       821572.0     15.683222
# 2           57791.0            30856.0       751985.0     16.616547
# 3           58580.0            30186.0       644476.0     15.508984
# 4           70588.0            34350.0       427031.0     13.004707
# 5           81851.0            37603.0       378459.0     11.992429
# 6           46338.0            25481.0       505182.0     18.692430
# 7           52782.0            29928.0       570731.0     21.658626
# 8           53626.0            29810.0       446611.0     17.498971
# 9           60807.0            25700.0       362215.0     15.380666
#
#    Unemployment Rate  Households with Internet  \
# 0           4.021741                 3295198.0
# 1           4.592977                 1956561.0
# 2           3.296683                 1562813.0
# 3           2.989050                 1489533.0
# 4           3.555722                 1111739.0
# 5           3.043238                 1024976.0
# 6           3.735955                  858289.0
# 7           4.059624                  944650.0
# 8           3.081287                  906179.0
# 9           4.559784                  711724.0
#
#    Households with Just Cell Data Plan  Households with DSL or Fiber Optic  \
# 0                             220563.0                           2306545.0
# 1                             135811.0                           1319255.0
# 2                             183317.0                            999605.0
# 3                             109769.0                           1058044.0
# 4                              62443.0                            876765.0
# 5                              65346.0                            809341.0
# 6                              58131.0                            551091.0
# 7                              51781.0                            645169.0
# 8                              92944.0                            571741.0
# 9                              49560.0                            515473.0
#
#    Households with Broadband Any Type  Households with Celular Data Plan  \
# 0                           2633021.0                          1680314.0
# 1                           1500290.0                           986543.0
# 2                           1225570.0                           848627.0
# 3                           1216868.0                           773917.0
# 4                            966430.0                           645331.0
# 5                            899047.0                           595764.0
# 6                            627883.0                           342068.0
# 7                            711897.0                           411665.0
# 8                            692870.0                           457642.0
# 9                            588200.0                           369086.0
#
#    Households with Just DSL or Fiber Optic  \
# 0                                 865663.0
# 1                                 465829.0
# 2                                 345502.0
# 3                                 400895.0
# 4                                 293588.0
# 5                                 281067.0
# 6                                 263935.0
# 7                                 281626.0
# 8                                 201750.0
# 9                                 195954.0
#
#    Households with Satellite Internet  \
# 0                            199009.0
# 1                             89105.0
# 2                             82925.0
# 3                             94168.0
# 4                             70951.0
# 5                             55099.0
# 6                             44337.0
# 7                             26654.0
# 8                             41337.0
# 9                             45073.0
#
#    Households with Just Satellite Internet  Households with No Internet  \
# 0                                  31351.0                     538359.0
# 1                                  13312.0                     359116.0
# 2                                  12605.0                     275630.0
# 3                                  18396.0                     216082.0
# 4                                   9144.0                     118026.0
# 5                                   6522.0                      97075.0
# 6                                   8004.0                     193906.0
# 7                                   3888.0                     200226.0
# 8                                   6080.0                     182720.0
# 9                                   7686.0                     101093.0
#
#          Lat         Lng
# 0  34.052227 -118.243660
# 1  41.737659  -87.697554
# 2  29.775182  -95.310250
# 3  33.291797 -112.429146
# 4  32.715730 -117.161097
# 5  33.717471 -117.831143
# 6  25.551603  -80.632692
# 7  40.678178  -73.944158
# 8  32.802468  -96.835100
# 9  33.953297 -117.396119

# %% [markdown]
# ### Add a Layer with Markers for the Ten Most Populated Counties

# %%
# Adding info boxes to the markers
info_box_template = """
<dl>
<dt>County</dt><dd>{Name}</dd>
<dt>Population</dt><dd>{Population}</dd>
<dt>Household with Celular Data</dt><dd>{Households with Celular Data Plan}</dd>
</dl>
"""
# Store the DataFrame Row
county_info = [info_box_template.format(**row) for index, row in top_ten.iterrows()]
locations = top_ten[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, hover_text="", label="", info_box_content=county_info, display_info_box=None)
# Add the marker layer
fig.add_layer(marker_layer)
## Show the Layer
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Cleaning Up Top 10 Most Populated Counties Dataframe

# %%
# Select Columns to Show
top_ten_clean = top_ten[[ 'Name', 'Population',
                'Households with Celular Data Plan',
                'Lat', 'Lng']]
# Show the Resulting Data Frame
top_ten_clean
# Out:
#                              Name  Population  \
# 0  Los Angeles County, California  10105722.0
# 1           Cook County, Illinois   5238541.0
# 2            Harris County, Texas   4525519.0
# 3        Maricopa County, Arizona   4155501.0
# 4    San Diego County, California   3283665.0
# 5       Orange County, California   3155816.0
# 6      Miami-Dade County, Florida   2702602.0
# 7          Kings County, New York   2635121.0
# 8            Dallas County, Texas   2552213.0
# 9    Riverside County, California   2355002.0
#
#    Households with Celular Data Plan        Lat         Lng
# 0                          1680314.0  34.052227 -118.243660
# 1                           986543.0  41.737659  -87.697554
# 2                           848627.0  29.775182  -95.310250
# 3                           773917.0  33.291797 -112.429146
# 4                           645331.0  32.715730 -117.161097
# 5                           595764.0  33.717471 -117.831143
# 6                           342068.0  25.551603  -80.632692
# 7                           411665.0  40.678178  -73.944158
# 8                           457642.0  32.802468  -96.835100
# 9                           369086.0  33.953297 -117.396119

# %% [markdown]
# ### Store the resulting dataframe

# %%
top_ten_clean.to_csv("output/top_ten_clean.csv", encoding="utf-8", index=False)
