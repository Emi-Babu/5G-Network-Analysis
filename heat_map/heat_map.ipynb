# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from config import gkey

# %%
heat_map_df = pd.read_csv('../coordinates/output/coordinates_pd.csv')
heat_map_df
# Out:
#       State                                  Name  Population  Median Age  \
# 0        72        Corozal Municipio, Puerto Rico     34933.0        38.1
# 1        72        Maunabo Municipio, Puerto Rico     11297.0        43.5
# 2        72       Peñuelas Municipio, Puerto Rico     21661.0        36.4
# 3        72          Ponce Municipio, Puerto Rico    148863.0        39.5
# 4        72  San Sebastián Municipio, Puerto Rico     38970.0        42.0
# ...     ...                                   ...         ...         ...
# 3215     55                Iowa County, Wisconsin     23576.0        42.5
# 3216     55               Pepin County, Wisconsin      7282.0        45.8
# 3217     55             Ozaukee County, Wisconsin     87817.0        43.9
# 3218     55             Portage County, Wisconsin     70371.0        36.6
# 3219     55            Richland County, Wisconsin     17626.0        44.8
#
#       Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0              14752.0             7887.0        19146.0     54.807775
# 1              17636.0             8830.0         5945.0     52.624591
# 2              16868.0             7983.0        12379.0     57.148793
# 3              16561.0            10775.0        75187.0     50.507514
# 4              14275.0             8072.0        21472.0     55.098794
# ...                ...                ...            ...           ...
# 3215           60017.0            31717.0         2100.0      8.907363
# 3216           51470.0            27901.0          938.0     12.881077
# 3217           80526.0            45820.0         5087.0      5.792728
# 3218           54620.0            28363.0         8757.0     12.444047
# 3219           48234.0            24941.0         2349.0     13.326903
#
#       Unemployment Rate  Households with Internet  \
# 0              9.435205                   11026.0
# 1              6.506152                    3976.0
# 2              7.391164                    7132.0
# 3              4.711043                   53341.0
# 4              8.486015                   14278.0
# ...                 ...                       ...
# 3215           1.895996                    9799.0
# 3216           1.757759                    3005.0
# 3217           1.637496                   35044.0
# 3218           2.569240                   28072.0
# 3219           1.753092                    7564.0
#
#       Households with Just Cell Data Plan  Households with DSL or Fiber Optic  \
# 0                                  2381.0                              2268.0
# 1                                   434.0                              1078.0
# 2                                  1361.0                              2329.0
# 3                                  5613.0                             18366.0
# 4                                  1525.0                              2446.0
# ...                                   ...                                 ...
# 3215                               1005.0                              5301.0
# 3216                                224.0                              1969.0
# 3217                               1978.0                             26993.0
# 3218                               2469.0                             19121.0
# 3219                                531.0                              3527.0
#
#       Households with Broadband Any Type  Households with Celular Data Plan  \
# 0                                 5021.0                             4088.0
# 1                                 1577.0                              987.0
# 2                                 3877.0                             3090.0
# 3                                25211.0                            17691.0
# 4                                 4743.0                             2737.0
# ...                                  ...                                ...
# 3215                              7486.0                             4180.0
# 3216                              2321.0                             1430.0
# 3217                             29934.0                            20099.0
# 3218                             22790.0                            14096.0
# 3219                              5161.0                             2487.0
#
#       Households with Just DSL or Fiber Optic  \
# 0                                       706.0
# 1                                       512.0
# 2                                       736.0
# 3                                      6802.0
# 4                                      1335.0
# ...                                       ...
# 3215                                   2566.0
# 3216                                    813.0
# 3217                                   9122.0
# 3218                                   7623.0
# 3219                                   1899.0
#
#       Households with Satellite Internet  \
# 0                                  361.0
# 1                                   77.0
# 2                                  181.0
# 3                                 1210.0
# 4                                  829.0
# ...                                  ...
# 3215                              1177.0
# 3216                               168.0
# 3217                              1763.0
# 3218                              1635.0
# 3219                              1108.0
#
#       Households with Just Satellite Internet  Households with No Internet  \
# 0                                       161.0                       5686.0
# 1                                        37.0                       2157.0
# 2                                        27.0                       2972.0
# 3                                       510.0                      25042.0
# 4                                       456.0                       8622.0
# ...                                       ...                          ...
# 3215                                    560.0                       1893.0
# 3216                                     35.0                        583.0
# 3217                                    277.0                       4033.0
# 3218                                    614.0                       4290.0
# 3219                                    636.0                       2023.0
#
#             Lat        Lng
# 0     18.341062 -66.316836
# 1     18.007189 -65.899329
# 2     18.063358 -66.727390
# 3     18.011077 -66.614062
# 4     18.335476 -66.994679
# ...         ...        ...
# 3215  42.941674 -90.074677
# 3216  44.645118 -92.027319
# 3217  43.381950 -87.618638
# 3218  44.473596 -89.474218
# 3219  43.406050 -90.374835
#
# [3220 rows x 20 columns]

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = heat_map_df[["Lat", "Lng"]].astype(float)
center_lat = (heat_map_df["Lat"].max() + heat_map_df["Lat"].min()) /2
center_lng = (heat_map_df["Lng"].max() + heat_map_df["Lng"].min()) /2

# %%
population = heat_map_df["Population"].astype(float)
max_intensity = population.max()

# %%
# Create a population Heatmap layer
fig = gmaps.figure()
fig = gmaps.figure(center = [center_lat,center_lng], zoom_level=1.8)
heat_layer = gmaps.heatmap_layer(locations, weights=population, 
                                 dissipating=False, max_intensity= max_intensity,
                                 point_radius = 5)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
