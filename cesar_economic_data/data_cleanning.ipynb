# %%
import pandas as pd

# %%
gdp = pd.read_csv('source/gdp.csv') 
gdp.head()
# Out:
#   Table 2. Real Gross Domestic Product (GDP) by Metropolitan Area, 2012-2017  \
# 0                                                NaN
# 1                                                NaN
# 2                            U.S. metropolitan areas
# 3                                        Abilene, TX
# 4                                          Akron, OH
#
#                            Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  Millions of chained (2009) dollars         NaN         NaN         NaN
# 1                                2012        2013        2014        2015
# 2                          13,692,212  13,891,109  14,219,922  14,671,751
# 3                               5,932       6,294       6,685       6,567
# 4                              28,581      29,301      30,800      32,011
#
#    Unnamed: 5  Unnamed: 6      Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN  Percent Change         NaN         NaN
# ...

# %%
population = pd.read_csv('source/population.csv', encoding="ISO-8859-1")
population.head()
# Out:
#       GEO.id GEO.id2 GEO.display-label GC.target-geo-id GC.target-geo-id2  \
# 0         Id     Id2         Geography    Target Geo Id    Target Geo Id2
# 1  0100000US     NaN     United States        0100000US               NaN
# 2  0100000US     NaN     United States        01000C0US               NaN
# 3  0100000US     NaN     United States   310M400US10180             10180
# 4  0100000US     NaN     United States   310M400US10420             10420
#
#                                    GC.display-label  \
# 0                                         Geography
# 1                                     United States
# 2  United States - In metropolitan statistical area
# 3            United States - Abilene, TX Metro Area
# 4              United States - Akron, OH Metro Area
#
#                  GC.display-label.1             rescen42010  \
# 0                         Geography  April 1, 2010 - Census
# 1                     United States               308745538
# ...

# %%
employment_change = pd.read_csv('source/employment_change.csv', encoding="ISO-8859-1")
employment_change.head()
# Out:
#   Over-the-year change in total nonfarm employment for metropolitan areas, not seasonally adjusted  \
# 0  To sort this table by a different column, clic...
# 1                                                NaN
# 2                       DisplayÊ102550100AllÊrecords
# 3                                Text search table:Ê
# 4                                  Metropolitan area
#
#   Unnamed: 1  Unnamed: 2     Unnamed: 3     Unnamed: 4     Unnamed: 5  \
# 0        NaN         NaN            NaN            NaN            NaN
# 1        NaN         NaN            NaN            NaN            NaN
# 2        NaN         NaN            NaN            NaN            NaN
# 3        NaN         NaN            NaN            NaN            NaN
# 4      State  Jul. 2018Ê  Jul. 2019Ê(p)  Over-the-year  Over-the-year
#
#      Unnamed: 6
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4  Significant?

# %%
unemployment = pd.read_csv('source/unemployment.csv', encoding="ISO-8859-1")
unemployment.head()
# Out:
#   Unemployment Rates for Metropolitan Areas, Not Seasonally Adjusted  \
# 0                                  Metropolitan area
# 1                                                NaN
# 2                                      United States
# 3                                                NaN
# 4  Burlington-South Burlington, VT Metropolitan N...
#
#      Unnamed: 1 Unnamed: 2
# 0  July 2019(P)       Rank
# 1          rate        NaN
# 2             4        NaN
# 3           NaN        NaN
# 4           1.8          1

# %%
wages = pd.read_csv('source/wages.csv', encoding="ISO-8859-1", low_memory = False)
wages.head()
# Out:
#   area_fips  own_code  industry_code  agglvl_code  size_code  year  qtr  \
# 0     01000         0             10           50          0  2017    3
# 1     01000         1             10           51          0  2017    3
# 2     01000         2             10           51          0  2017    3
# 3     01000         3             10           51          0  2017    3
# 4     01000         5             10           51          0  2017    3
#
#   disclosure_code  qtrly_estabs  month1_emplvl  ...  oty_month3_emplvl_chg  \
# 0             NaN        125237        1930604  ...                  17523
# 1             NaN          1205          53058  ...                   -607
# 2             NaN          1390          94443  ...                    507
# 3             NaN          3726         206464  ...                   1356
# 4             NaN        118916        1576639  ...                  16267
#
#    oty_month3_emplvl_pct_chg  oty_total_qtrly_wages_chg  \
# ...
